# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("spotify-tracks-dataset.csv", encoding="latin1")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id                 artists  \
# 0             0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1             1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2             2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3             3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4             4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy        73.0     230666.0    False         0.676
# ...

# %%
df.shape
# Out:
# (5929, 22)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'track_id', 'artists', 'album_name',
#        'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                0           0  5SuOikwiRyPMVoIQDJUgSV
# 1                1           1  4qPNDBW1i3p13qLCt0Ki3A
# 2                2           2  1iJBSr7s7jYXzM8EGcbK5b
# 3                3           3  6lfxq3CG4xtTiEg7opyCyx
# 4                4           4  5vjLSffimiIP26QG5WcN2K
# ...            ...         ...                     ...
# 5924          5924        5924  6tymkf3mb3JJxqd7wRS05t
# 5925          5925        5925  7mMshfkGDVQTjn03tvSlwI
# 5926          5926        5926  0lZ1SU9lES6W7y10LCMS9o
# 5927          5927        5927  1yn5VIHdxIlVMPRdQzR2sm
# 5928          5928        5928  6e5GvWg3K0qdhx3y9Si2mn
#
#                                                 artists  \
# 0                                           Gen Hoshino
# 1                                          Ben Woodward
# 2                                Ingrid Michaelson;ZAYN
# ...

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id                 artists  \
# 0             0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1             1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2             2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3             3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4             4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy        73.0     230666.0    False         0.676
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0   popularity   duration_ms  danceability  \
# count   5929.000000  5929.000000  5928.000000  5.928000e+03   5928.000000
# mean    2964.000000  2964.000000    36.297908  2.281407e+05      0.536196
# std     1711.699204  1711.699204    24.010367  7.873748e+04      0.167825
# min        0.000000     0.000000     0.000000  3.182400e+04      0.000000
# 25%     1482.000000  1482.000000    18.000000  1.821962e+05      0.429000
# 50%     2964.000000  2964.000000    43.000000  2.210655e+05      0.545000
# 75%     4446.000000  4446.000000    54.000000  2.606082e+05      0.660000
# max     5928.000000  5928.000000    93.000000  1.041520e+06      0.974000
#
#             energy          key     loudness         mode  speechiness  \
# count  5928.000000  5928.000000  5928.000000  5928.000000  5928.000000
# mean      0.585982     5.364879    -9.358904     0.619096     0.063325
# std       0.284183     3.554103     6.366654     0.485650     0.060550
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1        0
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          1
# popularity          1
# duration_ms         1
# explicit            1
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# time_signature      1
# track_genre         1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------------- ------------------------ 3.1/8.1 MB 37.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.1 MB 10.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 11.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.2 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 3.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.0/2.3 MB 2.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("spotify-tracks-dataset.csv", encoding="latin1")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0.1  Unnamed: 0                track_id  \
# 0                0           0  5SuOikwiRyPMVoIQDJUgSV
# 1                1           1  4qPNDBW1i3p13qLCt0Ki3A
# 2                2           2  1iJBSr7s7jYXzM8EGcbK5b
# 3                3           3  6lfxq3CG4xtTiEg7opyCyx
# 4                4           4  5vjLSffimiIP26QG5WcN2K
# ...            ...         ...                     ...
# 5924          5924        5924  6tymkf3mb3JJxqd7wRS05t
# 5925          5925        5925  7mMshfkGDVQTjn03tvSlwI
# 5926          5926        5926  0lZ1SU9lES6W7y10LCMS9o
# 5927          5927        5927  1yn5VIHdxIlVMPRdQzR2sm
# 5928          5928        5928  6e5GvWg3K0qdhx3y9Si2mn
#
#                                                 artists  \
# 0                                           Gen Hoshino
# 1                                          Ben Woodward
# 2                                Ingrid Michaelson;ZAYN
# ...

# %%
import matplotlib.pyplot as plt

df[['popularity','danceability','energy','tempo']].hist(figsize=(10,6))
plt.show()

# %%
df[['popularity','danceability','energy','tempo']].corr()
# Out:
#               popularity  danceability    energy     tempo
# popularity      1.000000     -0.121368 -0.167380 -0.026953
# danceability   -0.121368      1.000000  0.300787 -0.036199
# energy         -0.167380      0.300787  1.000000  0.214419
# tempo          -0.026953     -0.036199  0.214419  1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
df.boxplot(column=['popularity','tempo'])
plt.show()
